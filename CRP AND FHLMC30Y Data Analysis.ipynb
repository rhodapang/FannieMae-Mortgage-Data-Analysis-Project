# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_3=pd.read_excel('D:/1-Intern/Project_1/Data/CPR_Unemployment.xlsx')

# %%
df_1=pd.read_excel('D:/1-Intern/Project_1/Data/CPR_Economic index.xlsx')

# %%
df_4=pd.read_excel('D:/1-Intern/Project_1/Data/Unemployment_Roll_Rate.xlsx')

# %%
df_1
# Out:
#         Month  HPA index chain ratio       CPR  FHLMC30Y  \
# 0  2017-02-01               0.063918 -0.124298    4.1675
# 1  2017-03-01               0.062963  0.017319    4.1960
# 2  2017-04-01               0.066267  0.048553    4.0450
# 3  2017-05-01               0.065218  0.064765    4.0100
# 4  2017-06-01               0.062073  0.076805    3.9040
# 5  2017-07-01               0.063583  0.072684    3.9675
# 6  2017-08-01               0.066162  0.078629    3.8950
# 7  2017-09-01               0.064404  0.078691    3.8080
# 8  2017-10-01               0.064897  0.083218    3.8950
# 9  2017-11-01               0.066178  0.072894    3.9275
# 10 2017-12-01               0.064892  0.072800    3.9400
# 11 2018-01-01               0.074220  0.061271    4.0325
# 12 2018-02-01               0.074658  0.059599    4.3300
# 13 2018-03-01               0.071031  0.076419    4.4440
# 14 2018-04-01               0.066382  0.073046    4.4675
# ...

# %%
df_2=pd.read_excel('D:/1-Intern/Project_1/Data/Roll_Rate and Economic.xlsx') 
df_2
# Out:
#         Month  roll rate 0 to 30 days  roll rate 30 to 60  \
# 0  2014-07-01                0.003731            0.137931
# 1  2014-08-01                0.002984            0.068966
# 2  2014-09-01                0.002536            0.080268
# 3  2014-10-01                0.003377            0.071298
# 4  2014-11-01                0.002665            0.069967
# ..        ...                     ...                 ...
# 61 2019-08-01                0.005314            0.135772
# 62 2019-09-01                0.004670            0.139591
# 63 2019-10-01                0.006214            0.158839
# 64 2019-11-01                0.005176            0.127869
# 65 2019-12-01                0.000000            0.000000
#
#     HPA index chain ratio  FHLMC30Y  Unemployment Chain Ratio
# 0                0.044451    4.1325                 -0.164384
# 1                0.046431    4.1160                       NaN
# 2                0.041236    4.1625                       NaN
# ...

# %%
df_1=df_1.rename(columns={"Month": "Monthly_Reporting_Period"})

# %%
df_2=df_2.rename(columns={"Month": "Monthly_Reporting_Period"})

# %%
df_1['FHLMC30Y_Ratio']=df_1['FHLMC30Y'].pct_change()

# %%
df_1
# Out:
#    Monthly_Reporting_Period  HPA index chain ratio       CPR  FHLMC30Y  \
# 0                2017-02-01               0.063918 -0.124298    4.1675
# 1                2017-03-01               0.062963  0.017319    4.1960
# 2                2017-04-01               0.066267  0.048553    4.0450
# 3                2017-05-01               0.065218  0.064765    4.0100
# 4                2017-06-01               0.062073  0.076805    3.9040
# 5                2017-07-01               0.063583  0.072684    3.9675
# 6                2017-08-01               0.066162  0.078629    3.8950
# 7                2017-09-01               0.064404  0.078691    3.8080
# 8                2017-10-01               0.064897  0.083218    3.8950
# 9                2017-11-01               0.066178  0.072894    3.9275
# 10               2017-12-01               0.064892  0.072800    3.9400
# 11               2018-01-01               0.074220  0.061271    4.0325
# ...

# %%
df_2['FHLMC30Y_Ratio']=df_2['FHLMC30Y'].pct_change()

# %% [markdown]
# # CRP AND FHLMC30Y

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_1[['HPA index chain ratio','CPR','Unemployment Chain Ratio','FHLMC30Y_Ratio']] .plot()

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_1['Monthly_Reporting_Period'],df_1.CPR, color = 'red', label = 'CPR')
ax1.set_ylabel('CPR')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_1['Monthly_Reporting_Period'],df_1['FHLMC30Y_Ratio'], color = 'blue', label = 'FHLMC30Y_Ratio')
ax2.set_ylabel('FHLMC30Y_Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('CPR & FHLMC30Y_Ratio trend')
plt.show()

# %%
df_1['CPR'].corr(df_1['FHLMC30Y_Ratio'])
# Out:
# -0.1044647807440391

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_1['Monthly_Reporting_Period'],df_1.CPR, color = 'red', label = 'CPR')
ax1.set_ylabel('CPR')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_1['Monthly_Reporting_Period'],df_1['HPA index chain ratio'], color = 'blue', label = 'HPA index chain ratio')
ax2.set_ylabel('HPA index chain ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('CPR & HPA Index chain Ratio trend')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_1['Monthly_Reporting_Period'],df_1.CPR, color = 'red', label = 'CPR')
ax1.set_ylabel('CPR')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_1['Monthly_Reporting_Period'],df_1['Unemployment Chain Ratio']=df_1.loc[['Unemployment Chain Ratio'],dropna= True] , color = 'blue', label = 'Unemployment Chain Ratio',dropNA)
ax2.set_ylabel('Unemployment Chain Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('CPR & Unemployment Chain Ratio trend')
plt.show()
# Out:
#   File "<ipython-input-38-079f21c3c9bf>", line 9
#     ax2.plot(df_1['Monthly_Reporting_Period'],df_1['Unemployment Chain Ratio']=df_1.loc[['Unemployment Chain Ratio'],dropna= True] , color = 'blue', label = 'Unemployment Chain Ratio',dropNA)
#                                                                                                                            ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_1['Monthly_Reporting_Period'],df_1.CPR, color = 'red', label = 'CPR')
ax1.set_ylabel('CPR')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_1['Monthly_Reporting_Period'],df_1['Unemployment Chain Ratio'], color = 'blue', label = 'Unemployment Chain Ratio')
ax2.set_ylabel('Unemployment Chain Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('CPR & Unemployment Chain Ratio trend')
plt.show()

# %% [markdown]
# # CRP AND FHLMC30Y

# %%
df_2
# Out:
#    Monthly_Reporting_Period  roll rate 0 to 30 days  roll rate 30 to 60  \
# 0                2014-07-01                0.003731            0.137931
# 1                2014-08-01                0.002984            0.068966
# 2                2014-09-01                0.002536            0.080268
# 3                2014-10-01                0.003377            0.071298
# 4                2014-11-01                0.002665            0.069967
# ..                      ...                     ...                 ...
# 61               2019-08-01                0.005314            0.135772
# 62               2019-09-01                0.004670            0.139591
# 63               2019-10-01                0.006214            0.158839
# 64               2019-11-01                0.005176            0.127869
# 65               2019-12-01                0.000000            0.000000
#
#     HPA index chain ratio  FHLMC30Y  Unemployment Chain Ratio  FHLMC30Y_Ratio
# ...

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_2['Monthly_Reporting_Period'],df_2['roll rate 0 to 30 days'] , color = 'red', label = 'CPR')
ax1.set_ylabel('Roll Rate 0 to 30 days')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_2['Monthly_Reporting_Period'],df_2['FHLMC30Y_Ratio'], color = 'blue', label = 'FHLMC30Y_Ratio')
ax2.set_ylabel('FHLMC30Y_Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('Roll Rate 0 to 30 days & FHLMC30Y_Ratio trend')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_2['Monthly_Reporting_Period'],df_2['roll rate 0 to 30 days'] , color = 'red', label = 'CPR')
ax1.set_ylabel('Roll Rate 0 to 30 days')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_2['Monthly_Reporting_Period'],df_2['HPA index chain ratio'], color = 'blue', label = 'FHLMC30Y_Ratio')
ax2.set_ylabel('HPA Index Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('Roll Rate 0 to 30 days & HPA Index Ratio')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_2['Monthly_Reporting_Period'],df_2['roll rate 30 to 60'] , color = 'red', label = 'CPR')
ax1.set_ylabel('Roll Rate 30 to 60 days')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_2['Monthly_Reporting_Period'],df_2['FHLMC30Y_Ratio'], color = 'blue', label = 'FHLMC30Y_Ratio')
ax2.set_ylabel('FHLMC30Y_Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('Roll Rate 30 to 60 days & FHLMC30Y_Ratio trend')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_2['Monthly_Reporting_Period'],df_2['roll rate 30 to 60'] , color = 'red', label = 'CPR')
ax1.set_ylabel('Roll Rate 30 to 60 days')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_2['Monthly_Reporting_Period'],df_2['HPA index chain ratio'], color = 'blue', label = 'HPA index chain ratio')
ax2.set_ylabel('HPA index chain ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('Roll Rate 30 to 60 days & HPA index chain ratio')
plt.show()

# %%
df_3
# Out:
#         Month       CPR  Unemployment Chain Ratio
# 0  2017-04-01  0.048553                 -0.102041
# 1  2017-07-01  0.072684                 -0.122449
# 2  2017-10-01  0.083218                 -0.145833
# 3  2018-01-01  0.061271                 -0.108696
# 4  2018-04-01  0.073046                 -0.113636
# 5  2018-07-01  0.090944                 -0.116279
# 6  2018-10-01  0.079788                 -0.073171
# 7  2019-01-01  0.052804                 -0.048780
# 8  2019-04-01  0.095045                 -0.076923
# 9  2019-07-01  0.133388                 -0.052632
# 10 2019-10-01  0.152756                 -0.078947
# 11 2019-12-01  0.127456                 -0.025641

# %%
df_3=df_3.rename(columns={"Month": "Monthly_Reporting_Period"})

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_3['Monthly_Reporting_Period'],df_3.CPR, color = 'red', label = 'CPR')
ax1.set_ylabel('CPR')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_3['Monthly_Reporting_Period'],df_3['Unemployment Chain Ratio'], color = 'blue', label = 'Unemployment Chain Ratio')
ax2.set_ylabel('Unemployment Chain Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('CPR & Unemployment Chain Ratio Trend')
plt.show()

# %%
df_4=df_4.rename(columns={"Month": "Monthly_Reporting_Period"})

# %%
df_4
# Out:
#    Monthly_Reporting_Period  roll rate 0 to 30 days  roll rate 30 to 60  \
# 0                2014-07-01                0.003731            0.137931
# 1                2014-10-01                0.003377            0.071298
# 2                2015-01-01                0.003394            0.075542
# 3                2015-04-01                0.003187            0.111715
# 4                2015-07-01                0.003060            0.140659
# 5                2015-10-01                0.006351            0.139196
# 6                2016-01-01                0.004591            0.105945
# 7                2016-04-01                0.004176            0.122439
# 8                2016-07-01                0.004367            0.121074
# 9                2016-10-01                0.005082            0.134177
# 10               2017-01-01                0.005314            0.128590
# 11               2017-04-01                0.004147            0.110214
# ...

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_4['Monthly_Reporting_Period'],df_4['roll rate 0 to 30 days'] , color = 'red', label = 'CPR')
ax1.set_ylabel('Roll Rate 0 to 30 days')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_4['Monthly_Reporting_Period'],df_4['Unemployment Chain Ratio'], color = 'blue', label = 'Unemployment Chain Ratio')
ax2.set_ylabel('Unemployment Chain Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('Roll Rate 0 to 30 days & Unemployment Chain Ratio')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

ax1 = fig.add_subplot(111)
ax1.plot(df_4['Monthly_Reporting_Period'],df_4['roll rate 30 to 60'] , color = 'red', label = 'CPR')
ax1.set_ylabel('Roll Rate 30 to 60 days')
plt.legend()

ax2 = ax1.twinx()
ax2.plot(df_4['Monthly_Reporting_Period'],df_4['Unemployment Chain Ratio'], color = 'blue', label = 'Unemployment Chain Ratio')
ax2.set_ylabel('Unemployment Chain Ratio') 
plt.legend()

#plt.legend(handles=[ax1, ax2])
plt.xlabel('Monthly_Reporting_Period')
plt.title('Roll Rate 30 to 60 days & Unemployment Chain Ratio')
plt.show()

# %%
df_1['CPR'].corr(df_1['FHLMC30Y_Ratio'])
# Out:
# -0.1044647807440391

# %%
df_1['CPR'].corr(df_1['HPA index chain ratio'])
# Out:
# -0.441506573357489

# %%
df_3['CPR'].corr(df_3['Unemployment Chain Ratio'])
# Out:
# 0.4265892557006128

# %%
df_2['roll rate 0 to 30 days'].corr(df_2['FHLMC30Y_Ratio'])
# Out:
# -0.005334354811092886

# %%
df_2['roll rate 0 to 30 days'].corr(df_2['HPA index chain ratio'])
# Out:
# 0.4303091007673618

# %%
df_2
# Out:
#    Monthly_Reporting_Period  roll rate 0 to 30 days  roll rate 30 to 60  \
# 0                2014-07-01                0.003731            0.137931
# 1                2014-08-01                0.002984            0.068966
# 2                2014-09-01                0.002536            0.080268
# 3                2014-10-01                0.003377            0.071298
# 4                2014-11-01                0.002665            0.069967
# ..                      ...                     ...                 ...
# 61               2019-08-01                0.005314            0.135772
# 62               2019-09-01                0.004670            0.139591
# 63               2019-10-01                0.006214            0.158839
# 64               2019-11-01                0.005176            0.127869
# 65               2019-12-01                0.000000            0.000000
#
#     HPA index chain ratio  FHLMC30Y  Unemployment Chain Ratio  FHLMC30Y_Ratio
# ...

# %%
df_2['roll rate 30 to 60'].corr(df_2['FHLMC30Y_Ratio'])
# Out:
# 0.061589384314641

# %%
df_2['roll rate 30 to 60'].corr(df_2['HPA index chain ratio'])
# Out:
# 0.3939837964345122

# %%
df_3['CPR'].corr(df_3['Unemployment Chain Ratio'])
# Out:
# 0.4265892557006128

# %%
df_4['roll rate 30 to 60'].corr(df_4['Unemployment Chain Ratio'])
# Out:
# 0.11388475962044521

# %%
df_4['roll rate 0 to 30 days'].corr(df_4['Unemployment Chain Ratio'])
# Out:
# 0.48365891380261566
